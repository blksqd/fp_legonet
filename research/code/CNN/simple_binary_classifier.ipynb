# %%
import numpy as np
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
X, y = mnist['data'], mnist['target']
X.shape
# Out:
# (70000, 784)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt 

some_digit = X.iloc[0].to_numpy()

some_digit_image = some_digit.reshape(28,28)

plt.imshow(some_digit_image, cmap='binary')
plt.axis('off')
plt.show()

# %%
y = y.astype(np.uint8)
y.iloc[0]
# Out:
# 5

# %%
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

# %%
y_train_5 = (y_train == 5)
y_test_5 = (y_test == 5)

# %%
from sklearn.linear_model import SGDClassifier

# Train the SGD classifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train_5)
# Out:
# SGDClassifier(random_state=42)

# %%
sgd_clf.predict([some_digit])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /Users/andreshofmann/Desktop/Studies/Uol/7t/FP/stage_2/CNN/simple_binary_classifier.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/andreshofmann/Desktop/Studies/Uol/7t/FP/stage_2/CNN/simple_binary_classifier.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> sgd_clf.predict([some_digit])
#
# File ~/.pyenv/versions/3.12.2/envs/.venv/lib/python3.12/site-packages/sklearn/linear_model/_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File ~/.pyenv/versions/3.12.2/envs/.venv/lib/python3.12/site-packages/sklearn/linear_model/_base.py:329, in LinearClassifierMixin.decision_function(self, X)
#     310 def decision_function(self, X):
#     311     """
#     312     Predict confidence scores for samples.
#     313
#    (...)
#     327         this class would be predicted.
#     328     """
# --> 329     check_is_fitted(self)
#     330     xp, _ = get_namespace(X)
#     332     X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# File ~/.pyenv/versions/3.12.2/envs/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1619     raise TypeError("%s is not an estimator instance." % (estimator))
#    1621 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1622     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This SGDClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
